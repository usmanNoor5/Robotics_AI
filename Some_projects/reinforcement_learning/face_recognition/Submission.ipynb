# %%
import os
import random
import math
from PIL import Image
import numpy as np

# %%
DATA_DIR = "dataset"
FACE_DIR = os.path.join(DATA_DIR, "face")
NONFACE_DIR = os.path.join(DATA_DIR, "nonface")
IMAGE_SIZE = 64            # resize images to IMAGE_SIZE x IMAGE_SIZE (grayscale)
HIDDEN_UNITS = 128        # number of neurons in hidden layer
LEARNING_RATE = 0.01
EPOCHS = 40
BATCH_SIZE = 32
SEED = 42
MODEL_DIR = "model_weights"
VERBOSE = True

# %%
np.random.seed(SEED)
random.seed(SEED)

# %%
print("FACE_DIR:", os.path.abspath(FACE_DIR))
print("NONFACE_DIR:", os.path.abspath(NONFACE_DIR))

print("FACE EXISTS:", os.path.exists(FACE_DIR))
print("NONFACE EXISTS:", os.path.exists(NONFACE_DIR))

print("FACE LIST:", os.listdir(FACE_DIR) if os.path.exists(FACE_DIR) else "Missing")
print("NONFACE LIST:", os.listdir(NONFACE_DIR) if os.path.exists(NONFACE_DIR) else "Missing")
# Out:
# FACE_DIR: /home/usman/Documents/Robotics_AI/Some_projects/reinforcement_learning/face_recognition/dataset/face
# NONFACE_DIR: /home/usman/Documents/Robotics_AI/Some_projects/reinforcement_learning/face_recognition/dataset/nonface
# FACE EXISTS: True
# NONFACE EXISTS: True
# ...
