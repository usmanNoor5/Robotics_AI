# %%
import numpy as np 
import cv2

# %%
img= cv2.imread('./USman_model_data/usman_img_1.jpg')

# %%
# print(img)

# %%
# img.shape
small = cv2.resize(img, None, fx=0.2, fy=0.2, interpolation=cv2.INTER_AREA)
small.shape
# Out:
# (730, 547, 3)

# %%
# cv2.imshow('oringal',small)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
def display(winnkey,img):
    cv2.imshow(winnkey,img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# roi= small[0:300,0:300]
# display('acces',roi)

# %%
# img_cvt=cv2.cvtColor(small,cv2.COLOR_BGR2GRAY)
# display("gray_scale",img_cvt)

# %%
# img_cvt=cv2.cvtColor(small,cv2.COLOR_BGR2RGB)
# display("rgb",img_cvt)

# %%
# img_cvt=cv2.cvtColor(small,cv2.COLOR_BGR2HSV)
# display("HSV",img_cvt)

# %%
# img_cvt=cv2.cvtColor(small,cv2.COLOR_BGR2LAB)
# display("LAB",img_cvt)

# %%
canvas = np.zeros((300,300,3),dtype='uint8')
display('canvas',canvas)

# %%
pt1= (0,0)
pt2= (300,300)
color= (0,255,0)
cv2.line(canvas,pt1,pt2,color)
display('canvas',canvas)
